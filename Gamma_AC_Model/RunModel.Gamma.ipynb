# %%
import os

os.environ["OMP_NUM_THREADS"] = "4"
os.environ["MKL_NUM_THREADS"] = "4"
os.environ["OPENBLAS_NUM_THREADS"] = "4"
os.environ["NUMEXPR_NUM_THREADS"] = "4"

import torch  # Import PyTorch AFTER setting the environment variables
torch.set_num_threads(4)

# Verify
print(f"OMP_NUM_THREADS: {os.environ.get('OMP_NUM_THREADS')}")
print(f"MKL_NUM_THREADS: {os.environ.get('MKL_NUM_THREADS')}")
print(f"torch.get_num_threads(): {torch.get_num_threads()}")
# Out:
# OMP_NUM_THREADS: 4
# MKL_NUM_THREADS: 4
# torch.get_num_threads(): 4

# %%
import numpy as np
import subprocess
import sys
import torch_harmonics as th
import torch_harmonics.distributed as dist
import pandas as pd
import matplotlib.pyplot as plt
from subs1_utils import *

# %% [markdown]
# from dask.distributed import Client
# from dask.distributed import LocalCluster
#
# cluster = LocalCluster()
# cluster

# %%
# For MacOS is higher than 12.3+
if torch.backends.mps.is_available():
    print("Running on GPU")
#    print("Running on CPU")
    device = torch.device("mps")
#    device = torch.device("cpu")
    print("MPS is activated:",torch.backends.mps.is_built()) # Was the current version of PyTorch built with MPS activated?
else:
    print("Running  on CPU")
    device = torch.device("cpu")
    torch.set_num_threads(4)

device
# Out:
# Running  on CPU
# device(type='cpu')

# %%
# !taskset -p $$
# Out:
# pid 39437's current affinity mask: 3ffffff

# %%
### This cell initializes the model
###
###     First Define all spectral grids
###
zw = 63 # zonal wave number
mw = 63 # meridional wave number
kmax = 26
imax = 192
jmax = 96
steps_per_day = 216*1.5 ### Changing this number impliws time step changes and should
#                       be implemented carefully
#
#
# provide experiment name and data path for writing out data
# datapath may need to be edited for your system
#
expname = 'AC_warm'
foo = str(subprocess.check_output(['whoami']))
end = len(foo) - 3
uname = foo[2:end]
datapath = '/data/esplab/kpegion/projects/AGCM_Experiments/'+expname+'/'
prepath = '/data/esplab/kpegion/projects/AGCM/AnnualCycle/' #### Assumed to already exist and have preprocessing data
toffset = 0
#
times = pd.date_range(start = '1950-01-01', end='2100-01-01', freq='D') # The calendar month matters in this version with an
#                                                                        annual cycle
#
# If restart see below settings
#
#toffset = 60 # toffset is the number of days that have already run
datapath_init = datapath #set equal to datapath if restarting in same directory
#
if ( toffset == 0): # Cold Start
    subprocess.call(['rm','-r', datapath])
    subprocess.check_output(['mkdir', datapath])
#
# Get Day of Year at start of run
#
itime_ac = str(times[toffset])
year_ac = itime_ac[0:4]
mon_ac = itime_ac[5:7]
day_ac = itime_ac[8:10]
if ( mon_ac == '02' ) and ( day_ac == '29' ):
    day_ac = '28'
print(['Calendar for Annual Cycle',year_ac,mon_ac,day_ac])
newdate = pd.Timestamp('1951-'+mon_ac+'-'+day_ac)
daynumber=newdate.day_of_year - 1
print(['Day of Year Minus 1 at Start of Run',daynumber])
#
# Out:
# ['Calendar for Annual Cycle', '1950', '01', '01']
# ['Day of Year Minus 1 at Start of Run', 0]
# rm: cannot remove '/data/esplab/kpegion/projects/AGCM_Experiments/AC_warm/': No such file or directory

# %%
# Get the Gaussian latitudes and equally spaced longitudes
#
cost_lg, wlg, lats = precompute_latitudes(jmax)
lats = 90-180*lats/(np.pi)
lons = np.linspace(0.0,360.0-360.0/imax,imax)
Lon, Lat = np.meshgrid(lons, lats)
#
# Instantiate grid to spectral (dsht) and spectral to grid (disht) distibuted transforms
#
vsht = th.RealVectorSHT(jmax, imax, lmax=mw, mmax=zw, grid="legendre-gauss", csphase=False)
dsht = dist.DistributedRealSHT(jmax, imax, lmax=mw, mmax=zw, grid="legendre-gauss", csphase=False)
disht = dist.DistributedInverseRealSHT(jmax, imax, lmax=mw, mmax=zw, grid="legendre-gauss", csphase=False)
dvsht = dist.DistributedRealVectorSHT(jmax, imax, lmax=mw, mmax=zw, grid="legendre-gauss", csphase=False)
divsht = dist.DistributedInverseRealVectorSHT(jmax, imax, lmax=mw, mmax=zw, grid="legendre-gauss", csphase=False)

# %%
#
#
#
# Initialize spectral fields (at rest or to be read in)
def initialize(temp_newton,lnpsclim,kmax,mw,zw):
    for k in range (kmax):
        tmn1[k] = tmn1[k] + temp_newton[k]
        tmn2[k] = tmn2[k] + temp_newton[k]
        tmn3[k] = tmn3[k] + temp_newton[k]
    qmn1 = lnpsclim
    qmn2 = lnpsclim
    qmn3 = lnpsclim
    return tmn1,tmn2,tmn3,qmn1,qmn2,qmn3

# %%
#
# Initialization: Could read spectral restarts, or could
#              start at rest. If wanting to use grid point see
#              jupyter notebook preprocess
#              
#
# Implement at rest initial condition, but need coriolis since
# model predicts total vorticity
#
coriolis = np.broadcast_to([(4.0*np.pi/86400)*np.sin(lats[j,np.newaxis]*np.pi/180.0) for j in range(jmax)], (jmax, imax))
#
#
# Initialize spectral fields (at rest or to be read in)
# Need to read in background temperature data for Newtonian
# Relaxation and possible initialization, see preprocess
# for how to change source data or formulation.
#
temp_newton = torch.load(prepath+'temp.spectral.pt') # This is only used when initializing from a cold start
#                                    
#lnpsclim = torch.load(prepath+'lnps.spectral.pt') # lnps climatology for damping & for initializing a cold start
lnpsclim = torch.load(prepath+'lnps.spectral.pt') 
#
# Read Climatology on Gausian Grid
#
tclim_gg = torch.load(prepath+'tsig.ggrid.pt')
vortclim_gg = torch.load(prepath+'vortsig.ggrid.pt')
divclim_gg = torch.load(prepath+'divsig.ggrid.pt')
#
divclim = dsht(divclim_gg)
vortclim = dsht(vortclim_gg)
tclim = dsht(tclim_gg)
#
zmn1 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
zmn2 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
if ( toffset > 0 ): # Restart
    zmn1 = torch.load(datapath_init+'zmn1.spectral.pt')
    zmn2 = torch.load(datapath_init+'zmn2.spectral.pt')
zmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
#
dmn1 = torch.zeros((kmax,mw,zw),dtype=torch.complex128) 
dmn2 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
if ( toffset > 0 ): # Restart
    dmn1 = torch.load(datapath_init+'dmn1.spectral.pt')
    dmn2 = torch.load(datapath_init+'dmn2.spectral.pt')
dmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
#
tmn1 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
tmn2 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
if ( toffset > 0 ): # Restart
    tmn1 = torch.load(datapath_init+'tmn1.spectral.pt') 
    tmn2 = torch.load(datapath_init+'tmn2.spectral.pt')
tmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
#
wmn1 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
wmn2 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
wmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
#
qmn1 = torch.zeros((mw,zw),dtype=torch.complex128)
qmn2 = torch.zeros((mw,zw),dtype=torch.complex128)
if ( toffset > 0 ): # Restart
    qmn1 = torch.load(datapath_init+'qmn1.spectral.pt')
    qmn2 = torch.load(datapath_init+'qmn2.spectral.pt')
qmn3 = torch.zeros((mw,zw),dtype=torch.complex128)
#
#
if ( toffset == 0 ): # Only do this if cold start
    tmn1,tmn2,tmn3,qmn1,qmn2,qmn3 =\
    initialize(tclim[daynumber],lnpsclim[daynumber],kmax,mw,zw)
#
# Topography data - this should be spectral data or can be
#                        initialized to zero. If grid point data
#                        is desired see preprocess for how to
#                        convert to spectral. 
#
# Setting topography to zero here
#
###phismn = torch.zeros((mw,zw),dtype=torch.complex128)
#
# If non-zero topog read here
#
phismn = torch.load(prepath+'topog.spectral.pt')
#
#
# Read shape and scale for gamma rainfall distribution
#
shape = torch.load(prepath+'shapeAC_Warm.pt')
scale = torch.load(prepath+'scaleAC_Warm.pt')
#
# Out:
# /tmp/ipykernel_39387/3747338891.py:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   temp_newton = torch.load(prepath+'temp.spectral.pt') # This is only used when initializing from a cold start
# /tmp/ipykernel_39387/3747338891.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   lnpsclim = torch.load(prepath+'lnps.spectral.pt')
# /tmp/ipykernel_39387/3747338891.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   tclim_gg = torch.load(prepath+'tsig.ggrid.pt')
# /tmp/ipykernel_39387/3747338891.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   vortclim_gg = torch.load(prepath+'vortsig.ggrid.pt')
# /tmp/ipykernel_39387/3747338891.py:27: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   divclim_gg = torch.load(prepath+'divsig.ggrid.pt')
# /tmp/ipykernel_39387/3747338891.py:81: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   phismn = torch.load(prepath+'topog.spectral.pt')
# /tmp/ipykernel_39387/3747338891.py:86: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   shape = torch.load(prepath+'shapeAC_Warm.pt')
# /tmp/ipykernel_39387/3747338891.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   scale = torch.load(prepath+'scaleAC_Warm.pt')

# %%
###
### Constants, parameters, vertical differencing parameters,
### matricies for geopotential height, etc ...
###
delsig, si, sl, sikap, slkap, cth1, cth2, r1b, r2b = bscst(kmax)
### The above code is in subs1_utils.py - vertical structure related
### This code would need to be changed if the vertical resolution
### is changed - could be done by simply specifying delsig in bscst
###
amtrx, cmtrx, dmtrx = mcoeff(kmax,si,sl,slkap,r1b,r2b,delsig)
### The above code is for geopotential height and implicit scheme
### in subs1_utils.py but unlikely any changes would be needed
emtrx = inv_em(dmtrx,steps_per_day,kmax,mw,zw)
### The above code
### emtrix is used in the implicit time scheme, computed once here to save cpu time
### changes unlikely

# %%
#### Preprocessing is complete - now time to run model
#
#
# The Model Runs in 30-day chuncks - need to specify how many 30-day chunks to run
tl = 30 ##### tl is the chunk size - typically 30 days, but for testing 3 is reasonable
#
# Suggested ichunk for time dependent models: 120
#
ae = 6.371E+06 # Earth radius
tmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
zmnt = tmnt.detach().clone()
dmnt = tmnt.detach().clone()
qmnt = torch.zeros((tl,mw,zw),dtype=torch.complex128)
wmnt = tmnt.detach().clone()
heatt = torch.zeros((tl,kmax,jmax,imax),dtype=torch.float64)
#
ddtdiv = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
ddtvort = ddtdiv.detach().clone()
ttend = ddtdiv.detach().clone()
#
vort = torch.zeros((kmax,jmax,imax),dtype=torch.float64)
div = vort .detach().clone()
temp = vort.detach().clone()
qdot = vort.detach().clone()
#
# 
ichunk = 12
#
idays = tl * ichunk
#
#
#
#
# Begin Time Loop
#
ii = 0
savedat = 0
daycount = 0
total_days = 0
nstep = idays*steps_per_day
#
heat = latent_heat_release(dsht,disht,shape[daynumber],scale[daynumber],
                           imax,jmax,kmax,Lat,delsig,torch.Tensor.numpy(div[kmax-1]),ii)
#
while ii < nstep:
    ii = ii + 1
    savedat = savedat + 1
    zmnt[daycount] = zmnt[daycount] + zmn1/steps_per_day
    dmnt[daycount] = dmnt[daycount] + dmn1/steps_per_day
    tmnt[daycount] = tmnt[daycount] + tmn1/steps_per_day
    qmnt[daycount] = qmnt[daycount] + qmn1/steps_per_day
    wmnt[daycount] = wmnt[daycount] + wmn1/steps_per_day
    heatt[daycount] = heatt[daycount] + heat/steps_per_day
    if (savedat == steps_per_day): # post processing
        #
        #
        heat = latent_heat_release(dsht,disht,shape[daynumber],scale[daynumber],
                                   imax,jmax,kmax,Lat,delsig,torch.Tensor.numpy(div[kmax-1]),ii)
        #
        # Call Postprocessing Routine as needed
        #
        print((dmn1[10,2,2],dmn1[9,2,1]))
        print(('heat',heat[20,47,95]))
        daycount = daycount + 1
        total_days = total_days + 1
        print(['Day = ',total_days])
        print(['Date = ',times[total_days+toffset]])
        #
        itime_ac = str(times[total_days+toffset])
        year_ac = itime_ac[0:4]
        mon_ac = itime_ac[5:7]
        day_ac = itime_ac[8:10]
        if ( mon_ac == '02' ) and ( day_ac == '29' ):
            day_ac = '28'
        print(['Calendar for Annual Cycle',year_ac,mon_ac,day_ac])
        newdate = pd.Timestamp('1951-'+mon_ac+'-'+day_ac)
        daynumber=newdate.day_of_year - 1
        print(['Day of Year Minus 1',daynumber])
#
        if (daycount == tl):
            times_30day = times[total_days-tl+toffset:total_days+toffset]
            postprocessing(disht,divsht,zmnt,dmnt,tmnt,qmnt,wmnt,heatt,\
                           phismn,amtrx,times_30day,mw,zw,\
                           kmax,imax,jmax,sl,lats,lons,tl,datapath)
            tmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
            zmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
            dmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
            qmnt = torch.zeros((tl,mw,zw),dtype=torch.complex128)
            wmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
            daycount = 0
        savedat = 0
    #
    # Run model for one time step
    #
    # Spectral to grid transformation of needed fields:
    #   Vorticity, divergence, temperature, U, V, 
    #   grad(ln(Ps)), Q prescibed heating
    #
    #
    vort = disht(zmn2) ### This is the relative vorticity
    div = disht(dmn2)
    temp = disht(tmn2)
    qdot = disht(wmn2)
    u,v = uv(divsht,zmn2,dmn2,mw,zw,kmax,imax,jmax)
    dxq,dyq = gradq(divsht,qmn2,mw,zw,imax,jmax)
    #
    # Non-Linear products
    #
    a,b,e,ut,vt,ri,wj,cbar,dbar = nlprod(u,v,vort,div,temp,dxq,dyq,heat,coriolis,delsig,si,sikap,slkap,\
                                         r1b,r2b,cth1,cth2,cost_lg,kmax,imax,jmax)
    #
    #
    # Grid to spectral transformation of nlprod results
    #
    ddtdiv,ddtvort = vortdivspec(vsht,a,b,kmax,mw,zw)
    zmn3 = - ddtvort
    dmn3 = ddtdiv - lap_sht(dsht,e,mw,zw)
    _,ttend = vortdivspec(vsht,ut,vt,kmax,mw,zw)
    #
    tmn3 = -ttend + dsht(ri)
    wmn3 = dsht(wj) ### Prescribed heating converted to spectral
    qmn3 = -dsht(cbar) ### Only cbar here since dbar is included in implicit or explicit
    # 
    # Diffusion, Damping, Implicit or Explicit time differencing, Time filter
    #
    zmn3,dmn3,tmn3 = diffsn(zmn1,zmn3,dmn1,dmn3,tmn1,tmn3,mw,zw)
    #
    zmn3,dmn3,tmn3,qmn3 = damp_test(zmn1,zmn3,dmn1,dmn3,tmn1,tmn3,qmn1,qmn3,\
                          tclim[daynumber],lnpsclim[daynumber],vortclim[daynumber],divclim[daynumber],kmax,mw,zw)
    #
    dt = 86400.0/steps_per_day
    #
    zmn1,zmn2,zmn3,dmn1,dmn2,dmn3,tmn1,tmn2,tmn3,qmn1,qmn2,qmn3 = \
                        explicit(dt,amtrx,cmtrx,dmtrx,emtrx,\
                        zmn1,zmn2,zmn3,dmn1,dmn2,dmn3,tmn1,tmn2,\
                        tmn3,wmn1,wmn2,wmn3,qmn1,qmn2,qmn3,phismn,\
                        delsig,kmax,mw,zw)
    ####
    ## Reset zmn3, dmn3, tmn3,wmn3 & qmn3
    ###
    zmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
    dmn3 = zmn3.detach().clone()
    tmn3 = zmn3.detach().clone()
    wmn3 = zmn3.detach().clone()
    qmn3 = torch.zeros((mw,zw),dtype=torch.complex128)
#
# Done
# Out:
# (tensor(-4.0374e-08+4.6487e-07j, dtype=torch.complex128), tensor(2.1351e-07-1.1991e-08j, dtype=torch.complex128))
# ('heat', tensor(5.2668e-05, dtype=torch.float64))
# ['Day = ', 1]
# ['Date = ', Timestamp('1950-01-02 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '02']
# ['Day of Year Minus 1', 1]
# (tensor(4.2881e-07+5.8869e-07j, dtype=torch.complex128), tensor(-2.3825e-07-2.3988e-07j, dtype=torch.complex128))
# ('heat', tensor(3.0549e-05, dtype=torch.float64))
# ['Day = ', 2]
# ['Date = ', Timestamp('1950-01-03 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '03']
# ['Day of Year Minus 1', 2]
# (tensor(2.6716e-07+4.0665e-07j, dtype=torch.complex128), tensor(7.8971e-08-5.3935e-08j, dtype=torch.complex128))
# ('heat', tensor(7.9285e-05, dtype=torch.float64))
# ['Day = ', 3]
# ['Date = ', Timestamp('1950-01-04 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '04']
# ['Day of Year Minus 1', 3]
# (tensor(-1.4916e-07+2.2057e-07j, dtype=torch.complex128), tensor(-8.6031e-08+1.7265e-07j, dtype=torch.complex128))
# ('heat', tensor(1.2595e-05, dtype=torch.float64))
# ['Day = ', 4]
# ['Date = ', Timestamp('1950-01-05 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '05']
# ['Day of Year Minus 1', 4]
# (tensor(-6.5673e-07+5.7258e-07j, dtype=torch.complex128), tensor(-2.8892e-07+3.2149e-08j, dtype=torch.complex128))
# ('heat', tensor(4.5186e-05, dtype=torch.float64))
# ['Day = ', 5]
# ['Date = ', Timestamp('1950-01-06 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '06']
# ['Day of Year Minus 1', 5]
# (tensor(-1.0921e-07+5.6180e-07j, dtype=torch.complex128), tensor(-7.6785e-07+2.3809e-07j, dtype=torch.complex128))
# ('heat', tensor(5.7419e-05, dtype=torch.float64))
# ['Day = ', 6]
# ['Date = ', Timestamp('1950-01-07 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '07']
# ['Day of Year Minus 1', 6]
# (tensor(7.9954e-08+2.4553e-07j, dtype=torch.complex128), tensor(7.7665e-08-9.1683e-09j, dtype=torch.complex128))
# ('heat', tensor(3.3234e-05, dtype=torch.float64))
# ['Day = ', 7]
# ['Date = ', Timestamp('1950-01-08 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '08']
# ['Day of Year Minus 1', 7]
# (tensor(2.5638e-07+2.7252e-07j, dtype=torch.complex128), tensor(-4.4618e-08+6.2680e-09j, dtype=torch.complex128))
# ('heat', tensor(3.0326e-05, dtype=torch.float64))
# ['Day = ', 8]
# ['Date = ', Timestamp('1950-01-09 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '09']
# ['Day of Year Minus 1', 8]
# (tensor(5.2077e-07+5.0037e-07j, dtype=torch.complex128), tensor(-3.7217e-07+1.9665e-07j, dtype=torch.complex128))
# ('heat', tensor(0.0002, dtype=torch.float64))
# ['Day = ', 9]
# ['Date = ', Timestamp('1950-01-10 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '10']
# ['Day of Year Minus 1', 9]
# (tensor(4.1358e-07+3.5529e-07j, dtype=torch.complex128), tensor(-9.0745e-08+6.1665e-07j, dtype=torch.complex128))
# ('heat', tensor(9.3814e-05, dtype=torch.float64))
# ['Day = ', 10]
# ['Date = ', Timestamp('1950-01-11 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '11']
# ['Day of Year Minus 1', 10]
# (tensor(4.1501e-07+2.3228e-07j, dtype=torch.complex128), tensor(7.5230e-08+4.5600e-07j, dtype=torch.complex128))
# ('heat', tensor(4.2248e-05, dtype=torch.float64))
# ['Day = ', 11]
# ['Date = ', Timestamp('1950-01-12 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '12']
# ['Day of Year Minus 1', 11]
# (tensor(1.7298e-07+1.0034e-07j, dtype=torch.complex128), tensor(-4.6682e-07+1.3735e-07j, dtype=torch.complex128))
# ('heat', tensor(-4.6159e-06, dtype=torch.float64))
# ['Day = ', 12]
# ['Date = ', Timestamp('1950-01-13 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '13']
# ['Day of Year Minus 1', 12]
# (tensor(1.7014e-07+1.7843e-07j, dtype=torch.complex128), tensor(4.5970e-08+2.1594e-07j, dtype=torch.complex128))
# ('heat', tensor(0.0001, dtype=torch.float64))
# ['Day = ', 13]
# ['Date = ', Timestamp('1950-01-14 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '14']
# ['Day of Year Minus 1', 13]
# (tensor(5.7433e-07+3.9714e-07j, dtype=torch.complex128), tensor(1.6280e-07+6.6203e-07j, dtype=torch.complex128))
# ('heat', tensor(2.2781e-05, dtype=torch.float64))
# ['Day = ', 14]
# ['Date = ', Timestamp('1950-01-15 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '15']
# ['Day of Year Minus 1', 14]
# (tensor(1.4532e-07+4.5285e-08j, dtype=torch.complex128), tensor(-8.8477e-08+4.7413e-07j, dtype=torch.complex128))
# ('heat', tensor(5.8554e-05, dtype=torch.float64))
# ['Day = ', 15]
# ['Date = ', Timestamp('1950-01-16 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '16']
# ['Day of Year Minus 1', 15]
# (tensor(5.2846e-07+3.4559e-08j, dtype=torch.complex128), tensor(-2.2312e-07-6.8381e-08j, dtype=torch.complex128))
# ('heat', tensor(1.0652e-05, dtype=torch.float64))
# ['Day = ', 16]
# ['Date = ', Timestamp('1950-01-17 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '17']
# ['Day of Year Minus 1', 16]
# (tensor(5.9728e-07-5.3692e-08j, dtype=torch.complex128), tensor(-2.2426e-08+3.7064e-07j, dtype=torch.complex128))
# ('heat', tensor(4.9317e-05, dtype=torch.float64))
# ['Day = ', 17]
# ['Date = ', Timestamp('1950-01-18 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '18']
# ['Day of Year Minus 1', 17]
# (tensor(2.3058e-07+2.1157e-07j, dtype=torch.complex128), tensor(2.2113e-07+4.9437e-07j, dtype=torch.complex128))
# ('heat', tensor(5.3749e-05, dtype=torch.float64))
# ['Day = ', 18]
# ['Date = ', Timestamp('1950-01-19 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '19']
# ['Day of Year Minus 1', 18]
# (tensor(3.0959e-07+3.5491e-07j, dtype=torch.complex128), tensor(-2.2981e-08+3.0151e-07j, dtype=torch.complex128))
# ('heat', tensor(6.5059e-05, dtype=torch.float64))
# ['Day = ', 19]
# ['Date = ', Timestamp('1950-01-20 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '20']
# ['Day of Year Minus 1', 19]
# (tensor(2.5071e-07+4.7185e-07j, dtype=torch.complex128), tensor(-6.3937e-08+4.8721e-07j, dtype=torch.complex128))
# ('heat', tensor(1.3026e-05, dtype=torch.float64))
# ['Day = ', 20]
# ['Date = ', Timestamp('1950-01-21 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '21']
# ['Day of Year Minus 1', 20]
# (tensor(3.0995e-07+6.1000e-07j, dtype=torch.complex128), tensor(-2.0142e-07+2.8081e-07j, dtype=torch.complex128))
# ('heat', tensor(6.8642e-05, dtype=torch.float64))
# ['Day = ', 21]
# ['Date = ', Timestamp('1950-01-22 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '22']
# ['Day of Year Minus 1', 21]
# (tensor(5.0366e-07+4.0105e-07j, dtype=torch.complex128), tensor(-1.9859e-07+8.7177e-07j, dtype=torch.complex128))
# ('heat', tensor(7.5733e-05, dtype=torch.float64))
# ['Day = ', 22]
# ['Date = ', Timestamp('1950-01-23 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '23']
# ['Day of Year Minus 1', 22]
# (tensor(6.9097e-07+9.1928e-08j, dtype=torch.complex128), tensor(2.7119e-08+8.4971e-07j, dtype=torch.complex128))
# ('heat', tensor(0.0001, dtype=torch.float64))
# ['Day = ', 23]
# ['Date = ', Timestamp('1950-01-24 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '24']
# ['Day of Year Minus 1', 23]
# (tensor(5.3964e-07-2.2110e-07j, dtype=torch.complex128), tensor(-1.7372e-07+9.0295e-07j, dtype=torch.complex128))
# ('heat', tensor(6.6236e-05, dtype=torch.float64))
# ['Day = ', 24]
# ['Date = ', Timestamp('1950-01-25 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '25']
# ['Day of Year Minus 1', 24]
# (tensor(3.4331e-07-2.9699e-07j, dtype=torch.complex128), tensor(-2.5648e-07+8.2335e-07j, dtype=torch.complex128))
# ('heat', tensor(8.9009e-05, dtype=torch.float64))
# ['Day = ', 25]
# ['Date = ', Timestamp('1950-01-26 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '26']
# ['Day of Year Minus 1', 25]
# (tensor(1.9508e-07+9.7914e-08j, dtype=torch.complex128), tensor(3.4283e-07+6.7165e-07j, dtype=torch.complex128))
# ('heat', tensor(8.6382e-05, dtype=torch.float64))
# ['Day = ', 26]
# ['Date = ', Timestamp('1950-01-27 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '27']
# ['Day of Year Minus 1', 26]
# (tensor(3.7219e-07+1.7483e-07j, dtype=torch.complex128), tensor(2.1043e-07+7.8055e-07j, dtype=torch.complex128))
# ('heat', tensor(1.6486e-05, dtype=torch.float64))
# ['Day = ', 27]
# ['Date = ', Timestamp('1950-01-28 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '28']
# ['Day of Year Minus 1', 27]
# (tensor(2.3108e-07-4.5071e-08j, dtype=torch.complex128), tensor(7.5040e-09+3.9757e-07j, dtype=torch.complex128))
# ('heat', tensor(9.0756e-05, dtype=torch.float64))
# ['Day = ', 28]
# ['Date = ', Timestamp('1950-01-29 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '29']
# ['Day of Year Minus 1', 28]
# (tensor(6.9177e-08+2.5644e-07j, dtype=torch.complex128), tensor(2.4483e-07+8.0551e-07j, dtype=torch.complex128))
# ('heat', tensor(7.4858e-05, dtype=torch.float64))
# ['Day = ', 29]
# ['Date = ', Timestamp('1950-01-30 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '30']
# ['Day of Year Minus 1', 29]
# (tensor(2.8409e-07+1.6835e-07j, dtype=torch.complex128), tensor(-1.0739e-08+8.2598e-07j, dtype=torch.complex128))
# ('heat', tensor(0.0002, dtype=torch.float64))
# ['Day = ', 30]
# ['Date = ', Timestamp('1950-01-31 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '01', '31']
# ['Day of Year Minus 1', 30]
# (tensor(-1.1726e-08-1.3844e-07j, dtype=torch.complex128), tensor(-5.9494e-08+8.9575e-07j, dtype=torch.complex128))
# ('heat', tensor(1.1650e-05, dtype=torch.float64))
# ['Day = ', 31]
# ['Date = ', Timestamp('1950-02-01 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '01']
# ['Day of Year Minus 1', 31]
# (tensor(-1.7180e-08-9.8607e-08j, dtype=torch.complex128), tensor(-1.3868e-07+6.2988e-07j, dtype=torch.complex128))
# ('heat', tensor(4.6663e-05, dtype=torch.float64))
# ['Day = ', 32]
# ['Date = ', Timestamp('1950-02-02 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '02']
# ['Day of Year Minus 1', 32]
# (tensor(-2.9917e-07+1.8419e-07j, dtype=torch.complex128), tensor(4.5723e-07+5.5614e-07j, dtype=torch.complex128))
# ('heat', tensor(9.3437e-05, dtype=torch.float64))
# ['Day = ', 33]
# ['Date = ', Timestamp('1950-02-03 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '03']
# ['Day of Year Minus 1', 33]
# (tensor(-2.3918e-08+4.3209e-08j, dtype=torch.complex128), tensor(2.2565e-07+5.0569e-07j, dtype=torch.complex128))
# ('heat', tensor(6.1705e-05, dtype=torch.float64))
# ['Day = ', 34]
# ['Date = ', Timestamp('1950-02-04 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '04']
# ['Day of Year Minus 1', 34]
# (tensor(9.3896e-08+1.4689e-07j, dtype=torch.complex128), tensor(2.8480e-07+2.0849e-07j, dtype=torch.complex128))
# ('heat', tensor(4.6350e-05, dtype=torch.float64))
# ['Day = ', 35]
# ['Date = ', Timestamp('1950-02-05 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '05']
# ['Day of Year Minus 1', 35]
# (tensor(1.3342e-07+5.2281e-07j, dtype=torch.complex128), tensor(7.2114e-08+6.8159e-07j, dtype=torch.complex128))
# ('heat', tensor(0.0002, dtype=torch.float64))
# ['Day = ', 36]
# ['Date = ', Timestamp('1950-02-06 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '06']
# ['Day of Year Minus 1', 36]
# (tensor(-1.3570e-07+5.6260e-07j, dtype=torch.complex128), tensor(1.5596e-07+6.0889e-07j, dtype=torch.complex128))
# ('heat', tensor(8.3163e-06, dtype=torch.float64))
# ['Day = ', 37]
# ['Date = ', Timestamp('1950-02-07 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '07']
# ['Day of Year Minus 1', 37]
# (tensor(3.0473e-07+5.5634e-07j, dtype=torch.complex128), tensor(2.5142e-07+5.5294e-07j, dtype=torch.complex128))
# ('heat', tensor(1.2996e-06, dtype=torch.float64))
# ['Day = ', 38]
# ['Date = ', Timestamp('1950-02-08 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '08']
# ['Day of Year Minus 1', 38]
# (tensor(1.7924e-07+4.2812e-07j, dtype=torch.complex128), tensor(1.2482e-07+5.9822e-07j, dtype=torch.complex128))
# ('heat', tensor(2.1684e-05, dtype=torch.float64))
# ['Day = ', 39]
# ['Date = ', Timestamp('1950-02-09 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '09']
# ['Day of Year Minus 1', 39]
# (tensor(5.5197e-07+6.2784e-07j, dtype=torch.complex128), tensor(6.1455e-08+7.5209e-07j, dtype=torch.complex128))
# ('heat', tensor(5.5312e-05, dtype=torch.float64))
# ['Day = ', 40]
# ['Date = ', Timestamp('1950-02-10 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '10']
# ['Day of Year Minus 1', 40]
# (tensor(7.0661e-07+5.9942e-07j, dtype=torch.complex128), tensor(2.7691e-07+8.8058e-07j, dtype=torch.complex128))
# ('heat', tensor(9.6516e-05, dtype=torch.float64))
# ['Day = ', 41]
# ['Date = ', Timestamp('1950-02-11 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '11']
# ['Day of Year Minus 1', 41]
# (tensor(5.7618e-07-3.6523e-08j, dtype=torch.complex128), tensor(7.7813e-08+7.7659e-07j, dtype=torch.complex128))
# ('heat', tensor(7.7857e-06, dtype=torch.float64))
# ['Day = ', 42]
# ['Date = ', Timestamp('1950-02-12 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '12']
# ['Day of Year Minus 1', 42]
# (tensor(4.7402e-07+3.4924e-08j, dtype=torch.complex128), tensor(2.2477e-07+9.0640e-07j, dtype=torch.complex128))
# ('heat', tensor(4.5460e-05, dtype=torch.float64))
# ['Day = ', 43]
# ['Date = ', Timestamp('1950-02-13 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '13']
# ['Day of Year Minus 1', 43]
# (tensor(5.3891e-07+2.7467e-07j, dtype=torch.complex128), tensor(2.5056e-07+6.6036e-07j, dtype=torch.complex128))
# ('heat', tensor(4.8713e-05, dtype=torch.float64))
# ['Day = ', 44]
# ['Date = ', Timestamp('1950-02-14 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '14']
# ['Day of Year Minus 1', 44]
# (tensor(2.9987e-07-3.5092e-08j, dtype=torch.complex128), tensor(1.9705e-07+7.1476e-07j, dtype=torch.complex128))
# ('heat', tensor(-6.7947e-06, dtype=torch.float64))
# ['Day = ', 45]
# ['Date = ', Timestamp('1950-02-15 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '15']
# ['Day of Year Minus 1', 45]
# (tensor(7.4147e-08-1.5900e-08j, dtype=torch.complex128), tensor(1.8234e-07+7.0397e-07j, dtype=torch.complex128))
# ('heat', tensor(4.9339e-05, dtype=torch.float64))
# ['Day = ', 46]
# ['Date = ', Timestamp('1950-02-16 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '16']
# ['Day of Year Minus 1', 46]
# (tensor(-2.3331e-07+1.0109e-07j, dtype=torch.complex128), tensor(4.4186e-07+3.8787e-07j, dtype=torch.complex128))
# ('heat', tensor(0.0002, dtype=torch.float64))
# ['Day = ', 47]
# ['Date = ', Timestamp('1950-02-17 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '17']
# ['Day of Year Minus 1', 47]
# (tensor(-1.8775e-08+1.5084e-07j, dtype=torch.complex128), tensor(2.7936e-07+5.9570e-07j, dtype=torch.complex128))
# ('heat', tensor(5.7218e-05, dtype=torch.float64))
# ['Day = ', 48]
# ['Date = ', Timestamp('1950-02-18 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '18']
# ['Day of Year Minus 1', 48]
# (tensor(-2.9710e-07+2.5236e-07j, dtype=torch.complex128), tensor(2.4627e-07+4.6564e-07j, dtype=torch.complex128))
# ('heat', tensor(4.6098e-05, dtype=torch.float64))
# ['Day = ', 49]
# ['Date = ', Timestamp('1950-02-19 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '19']
# ['Day of Year Minus 1', 49]
# (tensor(-3.6667e-08+5.8582e-08j, dtype=torch.complex128), tensor(5.2441e-07+4.7330e-07j, dtype=torch.complex128))
# ('heat', tensor(1.9017e-05, dtype=torch.float64))
# ['Day = ', 50]
# ['Date = ', Timestamp('1950-02-20 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '20']
# ['Day of Year Minus 1', 50]
# (tensor(-3.1861e-07+2.6578e-07j, dtype=torch.complex128), tensor(4.3337e-07+5.4558e-07j, dtype=torch.complex128))
# ('heat', tensor(1.8524e-05, dtype=torch.float64))
# ['Day = ', 51]
# ['Date = ', Timestamp('1950-02-21 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '21']
# ['Day of Year Minus 1', 51]
# (tensor(-3.5956e-07+9.0828e-07j, dtype=torch.complex128), tensor(2.0595e-07+7.8491e-07j, dtype=torch.complex128))
# ('heat', tensor(5.5900e-05, dtype=torch.float64))
# ['Day = ', 52]
# ['Date = ', Timestamp('1950-02-22 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '22']
# ['Day of Year Minus 1', 52]
# (tensor(2.4447e-08+6.0839e-07j, dtype=torch.complex128), tensor(1.5350e-07+7.2620e-07j, dtype=torch.complex128))
# ('heat', tensor(1.9286e-06, dtype=torch.float64))
# ['Day = ', 53]
# ['Date = ', Timestamp('1950-02-23 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '23']
# ['Day of Year Minus 1', 53]
# (tensor(-3.9650e-08+4.0359e-07j, dtype=torch.complex128), tensor(3.5844e-07+6.6132e-07j, dtype=torch.complex128))
# ('heat', tensor(1.1762e-05, dtype=torch.float64))
# ['Day = ', 54]
# ['Date = ', Timestamp('1950-02-24 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '24']
# ['Day of Year Minus 1', 54]
# (tensor(6.9042e-08+8.7827e-07j, dtype=torch.complex128), tensor(7.3369e-08+5.0063e-07j, dtype=torch.complex128))
# ('heat', tensor(-5.5750e-07, dtype=torch.float64))
# ['Day = ', 55]
# ['Date = ', Timestamp('1950-02-25 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '25']
# ['Day of Year Minus 1', 55]
# (tensor(4.4884e-07+7.5925e-07j, dtype=torch.complex128), tensor(1.9893e-07+3.6876e-07j, dtype=torch.complex128))
# ('heat', tensor(5.6143e-05, dtype=torch.float64))
# ['Day = ', 56]
# ['Date = ', Timestamp('1950-02-26 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '26']
# ['Day of Year Minus 1', 56]
# (tensor(5.0647e-07+3.3773e-07j, dtype=torch.complex128), tensor(1.2482e-07+6.2574e-07j, dtype=torch.complex128))
# ('heat', tensor(5.7734e-05, dtype=torch.float64))
# ['Day = ', 57]
# ['Date = ', Timestamp('1950-02-27 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '27']
# ['Day of Year Minus 1', 57]
# (tensor(4.2205e-07+3.9380e-07j, dtype=torch.complex128), tensor(-1.2478e-07+4.4632e-07j, dtype=torch.complex128))
# ('heat', tensor(1.3677e-05, dtype=torch.float64))
# ['Day = ', 58]
# ['Date = ', Timestamp('1950-02-28 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '02', '28']
# ['Day of Year Minus 1', 58]
# (tensor(1.9758e-07+4.5576e-07j, dtype=torch.complex128), tensor(1.4682e-08+5.5805e-07j, dtype=torch.complex128))
# ('heat', tensor(9.7365e-06, dtype=torch.float64))
# ['Day = ', 59]
# ['Date = ', Timestamp('1950-03-01 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '01']
# ['Day of Year Minus 1', 59]
# (tensor(2.7816e-07+4.5887e-07j, dtype=torch.complex128), tensor(6.8694e-08+5.7829e-07j, dtype=torch.complex128))
# ('heat', tensor(1.2376e-05, dtype=torch.float64))
# ['Day = ', 60]
# ['Date = ', Timestamp('1950-03-02 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '02']
# ['Day of Year Minus 1', 60]
# (tensor(6.2214e-07+4.0571e-07j, dtype=torch.complex128), tensor(4.8900e-08+8.9037e-07j, dtype=torch.complex128))
# ('heat', tensor(-1.9885e-06, dtype=torch.float64))
# ['Day = ', 61]
# ['Date = ', Timestamp('1950-03-03 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '03']
# ['Day of Year Minus 1', 61]
# (tensor(3.2344e-07-1.0119e-07j, dtype=torch.complex128), tensor(9.3776e-08+7.1216e-07j, dtype=torch.complex128))
# ('heat', tensor(1.8432e-05, dtype=torch.float64))
# ['Day = ', 62]
# ['Date = ', Timestamp('1950-03-04 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '04']
# ['Day of Year Minus 1', 62]
# (tensor(1.7654e-09-1.5815e-08j, dtype=torch.complex128), tensor(7.4005e-08+6.0387e-07j, dtype=torch.complex128))
# ('heat', tensor(1.9386e-05, dtype=torch.float64))
# ['Day = ', 63]
# ['Date = ', Timestamp('1950-03-05 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '05']
# ['Day of Year Minus 1', 63]
# (tensor(-1.4544e-07+3.7059e-07j, dtype=torch.complex128), tensor(-3.5172e-08+7.6969e-07j, dtype=torch.complex128))
# ('heat', tensor(2.5982e-05, dtype=torch.float64))
# ['Day = ', 64]
# ['Date = ', Timestamp('1950-03-06 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '06']
# ['Day of Year Minus 1', 64]
# (tensor(2.9598e-07+1.2537e-07j, dtype=torch.complex128), tensor(1.3366e-09+6.2159e-07j, dtype=torch.complex128))
# ('heat', tensor(2.1455e-05, dtype=torch.float64))
# ['Day = ', 65]
# ['Date = ', Timestamp('1950-03-07 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '07']
# ['Day of Year Minus 1', 65]
# (tensor(-4.9428e-07-2.9794e-07j, dtype=torch.complex128), tensor(1.3262e-07+8.1875e-07j, dtype=torch.complex128))
# ('heat', tensor(8.2341e-05, dtype=torch.float64))
# ['Day = ', 66]
# ['Date = ', Timestamp('1950-03-08 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '08']
# ['Day of Year Minus 1', 66]
# (tensor(-4.6789e-07+3.5454e-07j, dtype=torch.complex128), tensor(1.5270e-07+3.9299e-07j, dtype=torch.complex128))
# ('heat', tensor(4.0282e-05, dtype=torch.float64))
# ['Day = ', 67]
# ['Date = ', Timestamp('1950-03-09 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '09']
# ['Day of Year Minus 1', 67]
# (tensor(2.1494e-07+6.2247e-07j, dtype=torch.complex128), tensor(2.6791e-07+5.3198e-07j, dtype=torch.complex128))
# ('heat', tensor(8.9663e-05, dtype=torch.float64))
# ['Day = ', 68]
# ['Date = ', Timestamp('1950-03-10 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '10']
# ['Day of Year Minus 1', 68]
# (tensor(4.7001e-07+3.3898e-07j, dtype=torch.complex128), tensor(6.3531e-08+7.1221e-07j, dtype=torch.complex128))
# ('heat', tensor(2.6009e-05, dtype=torch.float64))
# ['Day = ', 69]
# ['Date = ', Timestamp('1950-03-11 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '11']
# ['Day of Year Minus 1', 69]
# (tensor(4.5656e-07+2.8160e-07j, dtype=torch.complex128), tensor(1.6706e-07+8.7694e-07j, dtype=torch.complex128))
# ('heat', tensor(5.3396e-06, dtype=torch.float64))
# ['Day = ', 70]
# ['Date = ', Timestamp('1950-03-12 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '12']
# ['Day of Year Minus 1', 70]
# (tensor(2.4758e-07+2.0207e-07j, dtype=torch.complex128), tensor(-1.5786e-07+8.8724e-07j, dtype=torch.complex128))
# ('heat', tensor(4.9376e-05, dtype=torch.float64))
# ['Day = ', 71]
# ['Date = ', Timestamp('1950-03-13 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '13']
# ['Day of Year Minus 1', 71]
# (tensor(2.3340e-07+5.1312e-07j, dtype=torch.complex128), tensor(2.2565e-07+6.5154e-07j, dtype=torch.complex128))
# ('heat', tensor(-1.3752e-05, dtype=torch.float64))
# ['Day = ', 72]
# ['Date = ', Timestamp('1950-03-14 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '14']
# ['Day of Year Minus 1', 72]
# (tensor(4.1033e-07+6.1414e-07j, dtype=torch.complex128), tensor(8.0688e-08+9.4808e-07j, dtype=torch.complex128))
# ('heat', tensor(9.0882e-05, dtype=torch.float64))
# ['Day = ', 73]
# ['Date = ', Timestamp('1950-03-15 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '15']
# ['Day of Year Minus 1', 73]
# (tensor(5.7961e-07+3.4177e-07j, dtype=torch.complex128), tensor(2.2981e-07+7.3729e-07j, dtype=torch.complex128))
# ('heat', tensor(1.5960e-05, dtype=torch.float64))
# ['Day = ', 74]
# ['Date = ', Timestamp('1950-03-16 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '16']
# ['Day of Year Minus 1', 74]
# (tensor(4.3446e-07+3.0258e-07j, dtype=torch.complex128), tensor(1.1977e-07+4.1592e-07j, dtype=torch.complex128))
# ('heat', tensor(6.8159e-06, dtype=torch.float64))
# ['Day = ', 75]
# ['Date = ', Timestamp('1950-03-17 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '17']
# ['Day of Year Minus 1', 75]
# (tensor(5.6616e-07+3.4109e-07j, dtype=torch.complex128), tensor(2.3594e-07+6.2695e-07j, dtype=torch.complex128))
# ('heat', tensor(4.1870e-05, dtype=torch.float64))
# ['Day = ', 76]
# ['Date = ', Timestamp('1950-03-18 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '18']
# ['Day of Year Minus 1', 76]
# (tensor(8.8452e-07+1.3949e-07j, dtype=torch.complex128), tensor(3.8070e-07+7.3157e-07j, dtype=torch.complex128))
# ('heat', tensor(3.3212e-05, dtype=torch.float64))
# ['Day = ', 77]
# ['Date = ', Timestamp('1950-03-19 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '19']
# ['Day of Year Minus 1', 77]
# (tensor(2.2567e-07-1.9768e-07j, dtype=torch.complex128), tensor(-7.9937e-09+6.4254e-07j, dtype=torch.complex128))
# ('heat', tensor(8.8791e-06, dtype=torch.float64))
# ['Day = ', 78]
# ['Date = ', Timestamp('1950-03-20 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '20']
# ['Day of Year Minus 1', 78]
# (tensor(-4.3993e-08+4.7670e-07j, dtype=torch.complex128), tensor(2.3781e-07+5.1511e-07j, dtype=torch.complex128))
# ('heat', tensor(1.3591e-05, dtype=torch.float64))
# ['Day = ', 79]
# ['Date = ', Timestamp('1950-03-21 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '21']
# ['Day of Year Minus 1', 79]
# (tensor(1.8739e-07+7.5770e-07j, dtype=torch.complex128), tensor(3.0369e-07+6.2256e-07j, dtype=torch.complex128))
# ('heat', tensor(0.0001, dtype=torch.float64))
# ['Day = ', 80]
# ['Date = ', Timestamp('1950-03-22 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '22']
# ['Day of Year Minus 1', 80]
# (tensor(5.0161e-07+1.0107e-06j, dtype=torch.complex128), tensor(2.1898e-07+6.6491e-07j, dtype=torch.complex128))
# ('heat', tensor(2.0850e-05, dtype=torch.float64))
# ['Day = ', 81]
# ['Date = ', Timestamp('1950-03-23 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '23']
# ['Day of Year Minus 1', 81]
# (tensor(9.9534e-07+8.5268e-07j, dtype=torch.complex128), tensor(3.2555e-07+7.9444e-07j, dtype=torch.complex128))
# ('heat', tensor(1.6308e-05, dtype=torch.float64))
# ['Day = ', 82]
# ['Date = ', Timestamp('1950-03-24 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '24']
# ['Day of Year Minus 1', 82]
# (tensor(7.7132e-07+6.1199e-07j, dtype=torch.complex128), tensor(1.5964e-08+5.6710e-07j, dtype=torch.complex128))
# ('heat', tensor(2.6222e-05, dtype=torch.float64))
# ['Day = ', 83]
# ['Date = ', Timestamp('1950-03-25 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '25']
# ['Day of Year Minus 1', 83]
# (tensor(4.5189e-07+5.6650e-07j, dtype=torch.complex128), tensor(3.5388e-07+5.1362e-07j, dtype=torch.complex128))
# ('heat', tensor(3.2576e-05, dtype=torch.float64))
# ['Day = ', 84]
# ['Date = ', Timestamp('1950-03-26 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '26']
# ['Day of Year Minus 1', 84]
# (tensor(6.2330e-07+5.9945e-07j, dtype=torch.complex128), tensor(-7.3703e-08+5.2086e-07j, dtype=torch.complex128))
# ('heat', tensor(0.0001, dtype=torch.float64))
# ['Day = ', 85]
# ['Date = ', Timestamp('1950-03-27 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '27']
# ['Day of Year Minus 1', 85]
# (tensor(5.9818e-07+3.6017e-07j, dtype=torch.complex128), tensor(4.4134e-07+4.4691e-07j, dtype=torch.complex128))
# ('heat', tensor(1.9536e-05, dtype=torch.float64))
# ['Day = ', 86]
# ['Date = ', Timestamp('1950-03-28 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '28']
# ['Day of Year Minus 1', 86]
# (tensor(4.8849e-07+2.1655e-08j, dtype=torch.complex128), tensor(2.9564e-07+5.9434e-07j, dtype=torch.complex128))
# ('heat', tensor(3.8503e-05, dtype=torch.float64))
# ['Day = ', 87]
# ['Date = ', Timestamp('1950-03-29 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '29']
# ['Day of Year Minus 1', 87]
# (tensor(2.4795e-07+2.3107e-08j, dtype=torch.complex128), tensor(1.6001e-07+6.3506e-07j, dtype=torch.complex128))
# ('heat', tensor(2.3960e-05, dtype=torch.float64))
# ['Day = ', 88]
# ['Date = ', Timestamp('1950-03-30 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '30']
# ['Day of Year Minus 1', 88]
# (tensor(1.2244e-07+1.2399e-07j, dtype=torch.complex128), tensor(2.2281e-07+5.5759e-07j, dtype=torch.complex128))
# ('heat', tensor(2.2360e-05, dtype=torch.float64))
# ['Day = ', 89]
# ['Date = ', Timestamp('1950-03-31 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '03', '31']
# ['Day of Year Minus 1', 89]
# (tensor(2.3446e-07+4.0472e-07j, dtype=torch.complex128), tensor(9.2389e-08+2.7981e-07j, dtype=torch.complex128))
# ('heat', tensor(1.4290e-05, dtype=torch.float64))
# ['Day = ', 90]
# ['Date = ', Timestamp('1950-04-01 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '01']
# ['Day of Year Minus 1', 90]
# (tensor(2.7545e-07+3.0766e-07j, dtype=torch.complex128), tensor(2.1062e-07+3.3348e-07j, dtype=torch.complex128))
# ('heat', tensor(5.5622e-05, dtype=torch.float64))
# ['Day = ', 91]
# ['Date = ', Timestamp('1950-04-02 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '02']
# ['Day of Year Minus 1', 91]
# (tensor(2.1954e-07+5.6996e-07j, dtype=torch.complex128), tensor(2.7526e-08+4.1412e-07j, dtype=torch.complex128))
# ('heat', tensor(4.5578e-05, dtype=torch.float64))
# ['Day = ', 92]
# ['Date = ', Timestamp('1950-04-03 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '03']
# ['Day of Year Minus 1', 92]
# (tensor(2.4314e-07+7.4563e-07j, dtype=torch.complex128), tensor(1.6288e-07+2.8987e-07j, dtype=torch.complex128))
# ('heat', tensor(-7.3711e-06, dtype=torch.float64))
# ['Day = ', 93]
# ['Date = ', Timestamp('1950-04-04 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '04']
# ['Day of Year Minus 1', 93]
# (tensor(4.6121e-07+8.5575e-07j, dtype=torch.complex128), tensor(4.1727e-08+4.3591e-07j, dtype=torch.complex128))
# ('heat', tensor(4.9144e-05, dtype=torch.float64))
# ['Day = ', 94]
# ['Date = ', Timestamp('1950-04-05 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '05']
# ['Day of Year Minus 1', 94]
# (tensor(5.3654e-07+4.3750e-07j, dtype=torch.complex128), tensor(-1.8495e-08+3.7431e-07j, dtype=torch.complex128))
# ('heat', tensor(-2.6690e-05, dtype=torch.float64))
# ['Day = ', 95]
# ['Date = ', Timestamp('1950-04-06 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '06']
# ['Day of Year Minus 1', 95]
# (tensor(2.3830e-07+3.1612e-07j, dtype=torch.complex128), tensor(-6.4071e-08+4.3492e-07j, dtype=torch.complex128))
# ('heat', tensor(3.0358e-05, dtype=torch.float64))
# ['Day = ', 96]
# ['Date = ', Timestamp('1950-04-07 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '07']
# ['Day of Year Minus 1', 96]
# (tensor(7.0595e-08+5.0051e-07j, dtype=torch.complex128), tensor(-5.1401e-09+3.2785e-07j, dtype=torch.complex128))
# ('heat', tensor(1.3395e-05, dtype=torch.float64))
# ['Day = ', 97]
# ['Date = ', Timestamp('1950-04-08 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '08']
# ['Day of Year Minus 1', 97]
# (tensor(1.1529e-07+5.7176e-07j, dtype=torch.complex128), tensor(2.1391e-07+2.1589e-07j, dtype=torch.complex128))
# ('heat', tensor(8.8269e-06, dtype=torch.float64))
# ['Day = ', 98]
# ['Date = ', Timestamp('1950-04-09 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '09']
# ['Day of Year Minus 1', 98]
# (tensor(4.2636e-07+5.8827e-07j, dtype=torch.complex128), tensor(-9.6576e-08+4.1808e-07j, dtype=torch.complex128))
# ('heat', tensor(4.7445e-05, dtype=torch.float64))
# ['Day = ', 99]
# ['Date = ', Timestamp('1950-04-10 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '10']
# ['Day of Year Minus 1', 99]
# (tensor(3.0489e-07+5.5259e-07j, dtype=torch.complex128), tensor(5.4648e-08+3.3754e-07j, dtype=torch.complex128))
# ('heat', tensor(9.0787e-06, dtype=torch.float64))
# ['Day = ', 100]
# ['Date = ', Timestamp('1950-04-11 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '11']
# ['Day of Year Minus 1', 100]
# (tensor(2.0897e-07+6.2356e-07j, dtype=torch.complex128), tensor(-1.9971e-08+1.1049e-07j, dtype=torch.complex128))
# ('heat', tensor(4.1918e-05, dtype=torch.float64))
# ['Day = ', 101]
# ['Date = ', Timestamp('1950-04-12 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '12']
# ['Day of Year Minus 1', 101]
# (tensor(2.6329e-07+6.3674e-07j, dtype=torch.complex128), tensor(5.0098e-08+8.9320e-08j, dtype=torch.complex128))
# ('heat', tensor(-7.5968e-08, dtype=torch.float64))
# ['Day = ', 102]
# ['Date = ', Timestamp('1950-04-13 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '13']
# ['Day of Year Minus 1', 102]
# (tensor(3.5624e-07+5.7882e-07j, dtype=torch.complex128), tensor(1.5420e-07+3.2040e-07j, dtype=torch.complex128))
# ('heat', tensor(-2.2937e-06, dtype=torch.float64))
# ['Day = ', 103]
# ['Date = ', Timestamp('1950-04-14 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '14']
# ['Day of Year Minus 1', 103]
# (tensor(-5.5338e-08+6.5167e-07j, dtype=torch.complex128), tensor(6.0889e-08+2.1616e-07j, dtype=torch.complex128))
# ('heat', tensor(4.1846e-05, dtype=torch.float64))
# ['Day = ', 104]
# ['Date = ', Timestamp('1950-04-15 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '15']
# ['Day of Year Minus 1', 104]
# (tensor(6.5813e-08+8.9147e-07j, dtype=torch.complex128), tensor(-1.0521e-07+2.5476e-07j, dtype=torch.complex128))
# ('heat', tensor(2.8812e-05, dtype=torch.float64))
# ['Day = ', 105]
# ['Date = ', Timestamp('1950-04-16 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '16']
# ['Day of Year Minus 1', 105]
# (tensor(2.5145e-07+9.6725e-07j, dtype=torch.complex128), tensor(-5.7432e-08+2.4971e-07j, dtype=torch.complex128))
# ('heat', tensor(-1.0487e-05, dtype=torch.float64))
# ['Day = ', 106]
# ['Date = ', Timestamp('1950-04-17 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '17']
# ['Day of Year Minus 1', 106]
# (tensor(3.1106e-07+7.8296e-07j, dtype=torch.complex128), tensor(5.8227e-08+2.1026e-07j, dtype=torch.complex128))
# ('heat', tensor(2.7150e-05, dtype=torch.float64))
# ['Day = ', 107]
# ['Date = ', Timestamp('1950-04-18 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '18']
# ['Day of Year Minus 1', 107]
# (tensor(2.3223e-07+6.5448e-07j, dtype=torch.complex128), tensor(-1.9837e-07+3.6858e-07j, dtype=torch.complex128))
# ('heat', tensor(-2.2515e-06, dtype=torch.float64))
# ['Day = ', 108]
# ['Date = ', Timestamp('1950-04-19 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '19']
# ['Day of Year Minus 1', 108]
# (tensor(1.8708e-07+5.9287e-07j, dtype=torch.complex128), tensor(-1.1141e-07+3.6071e-07j, dtype=torch.complex128))
# ('heat', tensor(-5.9377e-06, dtype=torch.float64))
# ['Day = ', 109]
# ['Date = ', Timestamp('1950-04-20 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '20']
# ['Day of Year Minus 1', 109]
# (tensor(2.5704e-07+4.3476e-07j, dtype=torch.complex128), tensor(-1.1948e-07+2.8267e-07j, dtype=torch.complex128))
# ('heat', tensor(2.6500e-05, dtype=torch.float64))
# ['Day = ', 110]
# ['Date = ', Timestamp('1950-04-21 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '21']
# ['Day of Year Minus 1', 110]
# (tensor(1.0692e-07+8.1276e-08j, dtype=torch.complex128), tensor(-1.7453e-07+6.1818e-08j, dtype=torch.complex128))
# ('heat', tensor(5.4840e-05, dtype=torch.float64))
# ['Day = ', 111]
# ['Date = ', Timestamp('1950-04-22 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '22']
# ['Day of Year Minus 1', 111]
# (tensor(1.0165e-07-7.6516e-08j, dtype=torch.complex128), tensor(-2.1766e-07+2.6504e-07j, dtype=torch.complex128))
# ('heat', tensor(4.5775e-06, dtype=torch.float64))
# ['Day = ', 112]
# ['Date = ', Timestamp('1950-04-23 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '23']
# ['Day of Year Minus 1', 112]
# (tensor(-1.0482e-07+3.9376e-08j, dtype=torch.complex128), tensor(-1.5475e-07+2.7308e-07j, dtype=torch.complex128))
# ('heat', tensor(3.6534e-05, dtype=torch.float64))
# ['Day = ', 113]
# ['Date = ', Timestamp('1950-04-24 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '24']
# ['Day of Year Minus 1', 113]
# (tensor(4.5754e-08-7.7101e-08j, dtype=torch.complex128), tensor(-4.0478e-08+3.6579e-07j, dtype=torch.complex128))
# ('heat', tensor(-8.2991e-06, dtype=torch.float64))
# ['Day = ', 114]
# ['Date = ', Timestamp('1950-04-25 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '25']
# ['Day of Year Minus 1', 114]
# (tensor(-8.6470e-08-7.0219e-08j, dtype=torch.complex128), tensor(-1.6033e-07+2.1845e-07j, dtype=torch.complex128))
# ('heat', tensor(2.6255e-05, dtype=torch.float64))
# ['Day = ', 115]
# ['Date = ', Timestamp('1950-04-26 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '26']
# ['Day of Year Minus 1', 115]
# (tensor(-1.9995e-07+2.4415e-07j, dtype=torch.complex128), tensor(-2.2606e-07+2.2158e-07j, dtype=torch.complex128))
# ('heat', tensor(-3.7368e-06, dtype=torch.float64))
# ['Day = ', 116]
# ['Date = ', Timestamp('1950-04-27 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '27']
# ['Day of Year Minus 1', 116]
# (tensor(1.5693e-07+3.0859e-07j, dtype=torch.complex128), tensor(-4.1468e-07+1.9084e-07j, dtype=torch.complex128))
# ('heat', tensor(3.4053e-05, dtype=torch.float64))
# ['Day = ', 117]
# ['Date = ', Timestamp('1950-04-28 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '28']
# ['Day of Year Minus 1', 117]
# (tensor(3.8387e-07+2.4123e-07j, dtype=torch.complex128), tensor(-2.2674e-07+2.2484e-07j, dtype=torch.complex128))
# ('heat', tensor(-6.7314e-06, dtype=torch.float64))
# ['Day = ', 118]
# ['Date = ', Timestamp('1950-04-29 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '29']
# ['Day of Year Minus 1', 118]
# (tensor(2.3596e-07+1.6245e-07j, dtype=torch.complex128), tensor(3.1004e-09+2.8978e-07j, dtype=torch.complex128))
# ('heat', tensor(0.0001, dtype=torch.float64))
# ['Day = ', 119]
# ['Date = ', Timestamp('1950-04-30 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '04', '30']
# ['Day of Year Minus 1', 119]
# (tensor(5.7404e-08+4.9472e-07j, dtype=torch.complex128), tensor(-1.7086e-07+2.2802e-07j, dtype=torch.complex128))
# ('heat', tensor(7.6481e-05, dtype=torch.float64))
# ['Day = ', 120]
# ['Date = ', Timestamp('1950-05-01 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '01']
# ['Day of Year Minus 1', 120]
# (tensor(1.0888e-07+5.7093e-07j, dtype=torch.complex128), tensor(-9.2168e-08+2.7100e-08j, dtype=torch.complex128))
# ('heat', tensor(4.8640e-05, dtype=torch.float64))
# ['Day = ', 121]
# ['Date = ', Timestamp('1950-05-02 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '02']
# ['Day of Year Minus 1', 121]
# (tensor(2.7013e-07+2.7687e-07j, dtype=torch.complex128), tensor(-4.4705e-08+3.2203e-07j, dtype=torch.complex128))
# ('heat', tensor(1.3914e-05, dtype=torch.float64))
# ['Day = ', 122]
# ['Date = ', Timestamp('1950-05-03 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '03']
# ['Day of Year Minus 1', 122]
# (tensor(2.1795e-07+1.4914e-07j, dtype=torch.complex128), tensor(-1.6413e-07+2.4415e-07j, dtype=torch.complex128))
# ('heat', tensor(9.7183e-06, dtype=torch.float64))
# ['Day = ', 123]
# ['Date = ', Timestamp('1950-05-04 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '04']
# ['Day of Year Minus 1', 123]
# (tensor(2.3193e-07+4.2343e-07j, dtype=torch.complex128), tensor(-1.5692e-07+1.4468e-07j, dtype=torch.complex128))
# ('heat', tensor(2.4977e-05, dtype=torch.float64))
# ['Day = ', 124]
# ['Date = ', Timestamp('1950-05-05 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '05']
# ['Day of Year Minus 1', 124]
# (tensor(3.6069e-07+4.4334e-07j, dtype=torch.complex128), tensor(-4.3021e-07+2.9702e-07j, dtype=torch.complex128))
# ('heat', tensor(-2.7669e-06, dtype=torch.float64))
# ['Day = ', 125]
# ['Date = ', Timestamp('1950-05-06 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '06']
# ['Day of Year Minus 1', 125]
# (tensor(4.3455e-07+2.8117e-07j, dtype=torch.complex128), tensor(-3.1558e-07+2.8519e-07j, dtype=torch.complex128))
# ('heat', tensor(-4.1356e-06, dtype=torch.float64))
# ['Day = ', 126]
# ['Date = ', Timestamp('1950-05-07 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '07']
# ['Day of Year Minus 1', 126]
# (tensor(5.0473e-07+3.1976e-07j, dtype=torch.complex128), tensor(-4.1462e-07+2.9306e-07j, dtype=torch.complex128))
# ('heat', tensor(7.1669e-06, dtype=torch.float64))
# ['Day = ', 127]
# ['Date = ', Timestamp('1950-05-08 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '08']
# ['Day of Year Minus 1', 127]
# (tensor(3.4388e-07+8.9251e-08j, dtype=torch.complex128), tensor(-3.2068e-07+8.3561e-08j, dtype=torch.complex128))
# ('heat', tensor(-3.1980e-06, dtype=torch.float64))
# ['Day = ', 128]
# ['Date = ', Timestamp('1950-05-09 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '09']
# ['Day of Year Minus 1', 128]
# (tensor(2.9351e-07+1.6845e-07j, dtype=torch.complex128), tensor(-2.2689e-07+3.5100e-07j, dtype=torch.complex128))
# ('heat', tensor(6.4403e-07, dtype=torch.float64))
# ['Day = ', 129]
# ['Date = ', Timestamp('1950-05-10 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '10']
# ['Day of Year Minus 1', 129]
# (tensor(2.8370e-07+1.6523e-07j, dtype=torch.complex128), tensor(-4.1406e-07+1.6636e-07j, dtype=torch.complex128))
# ('heat', tensor(1.2300e-05, dtype=torch.float64))
# ['Day = ', 130]
# ['Date = ', Timestamp('1950-05-11 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '11']
# ['Day of Year Minus 1', 130]
# (tensor(2.3393e-07+1.1202e-07j, dtype=torch.complex128), tensor(-2.6657e-07+3.1059e-07j, dtype=torch.complex128))
# ('heat', tensor(-1.7891e-06, dtype=torch.float64))
# ['Day = ', 131]
# ['Date = ', Timestamp('1950-05-12 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '12']
# ['Day of Year Minus 1', 131]
# (tensor(-1.3489e-07+1.6842e-07j, dtype=torch.complex128), tensor(-3.7545e-07+4.3199e-07j, dtype=torch.complex128))
# ('heat', tensor(-1.9155e-06, dtype=torch.float64))
# ['Day = ', 132]
# ['Date = ', Timestamp('1950-05-13 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '13']
# ['Day of Year Minus 1', 132]
# (tensor(-5.5134e-08+4.0021e-07j, dtype=torch.complex128), tensor(-3.8214e-07+3.3027e-07j, dtype=torch.complex128))
# ('heat', tensor(1.5402e-06, dtype=torch.float64))
# ['Day = ', 133]
# ['Date = ', Timestamp('1950-05-14 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '14']
# ['Day of Year Minus 1', 133]
# (tensor(1.1676e-08+3.9021e-07j, dtype=torch.complex128), tensor(-3.3369e-07+4.2564e-07j, dtype=torch.complex128))
# ('heat', tensor(4.9162e-06, dtype=torch.float64))
# ['Day = ', 134]
# ['Date = ', Timestamp('1950-05-15 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '15']
# ['Day of Year Minus 1', 134]
# (tensor(8.9440e-08+4.4230e-07j, dtype=torch.complex128), tensor(-2.6680e-07+3.2924e-07j, dtype=torch.complex128))
# ('heat', tensor(4.3497e-06, dtype=torch.float64))
# ['Day = ', 135]
# ['Date = ', Timestamp('1950-05-16 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '16']
# ['Day of Year Minus 1', 135]
# (tensor(-5.9450e-08+8.6093e-08j, dtype=torch.complex128), tensor(-3.1938e-07+5.1957e-07j, dtype=torch.complex128))
# ('heat', tensor(-1.7018e-06, dtype=torch.float64))
# ['Day = ', 136]
# ['Date = ', Timestamp('1950-05-17 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '17']
# ['Day of Year Minus 1', 136]
# (tensor(-9.2370e-08+2.9970e-07j, dtype=torch.complex128), tensor(-3.3714e-07+2.5254e-07j, dtype=torch.complex128))
# ('heat', tensor(8.5104e-05, dtype=torch.float64))
# ['Day = ', 137]
# ['Date = ', Timestamp('1950-05-18 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '18']
# ['Day of Year Minus 1', 137]
# (tensor(1.9811e-08+5.2022e-07j, dtype=torch.complex128), tensor(-3.1711e-08+3.8705e-07j, dtype=torch.complex128))
# ('heat', tensor(2.6783e-07, dtype=torch.float64))
# ['Day = ', 138]
# ['Date = ', Timestamp('1950-05-19 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '19']
# ['Day of Year Minus 1', 138]
# (tensor(2.5417e-07+3.6184e-07j, dtype=torch.complex128), tensor(-2.0837e-07+4.9160e-07j, dtype=torch.complex128))
# ('heat', tensor(8.3463e-06, dtype=torch.float64))
# ['Day = ', 139]
# ['Date = ', Timestamp('1950-05-20 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '20']
# ['Day of Year Minus 1', 139]
# (tensor(2.0751e-07+8.4513e-08j, dtype=torch.complex128), tensor(-2.2842e-07+3.3982e-07j, dtype=torch.complex128))
# ('heat', tensor(2.3346e-05, dtype=torch.float64))
# ['Day = ', 140]
# ['Date = ', Timestamp('1950-05-21 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '21']
# ['Day of Year Minus 1', 140]
# (tensor(-9.7821e-09+1.9873e-07j, dtype=torch.complex128), tensor(-2.9865e-07+2.9129e-07j, dtype=torch.complex128))
# ('heat', tensor(3.2949e-06, dtype=torch.float64))
# ['Day = ', 141]
# ['Date = ', Timestamp('1950-05-22 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '22']
# ['Day of Year Minus 1', 141]
# (tensor(7.4612e-08+2.0515e-07j, dtype=torch.complex128), tensor(-1.5060e-07+5.1560e-08j, dtype=torch.complex128))
# ('heat', tensor(-4.0793e-06, dtype=torch.float64))
# ['Day = ', 142]
# ['Date = ', Timestamp('1950-05-23 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '23']
# ['Day of Year Minus 1', 142]
# (tensor(-6.2631e-08+1.7015e-07j, dtype=torch.complex128), tensor(-2.7258e-07+3.4027e-07j, dtype=torch.complex128))
# ('heat', tensor(-4.5715e-06, dtype=torch.float64))
# ['Day = ', 143]
# ['Date = ', Timestamp('1950-05-24 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '24']
# ['Day of Year Minus 1', 143]
# (tensor(9.0226e-08+1.5399e-07j, dtype=torch.complex128), tensor(-4.8404e-07+1.6667e-07j, dtype=torch.complex128))
# ('heat', tensor(2.8494e-05, dtype=torch.float64))
# ['Day = ', 144]
# ['Date = ', Timestamp('1950-05-25 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '25']
# ['Day of Year Minus 1', 144]
# (tensor(1.1141e-07+1.9009e-07j, dtype=torch.complex128), tensor(-1.1625e-07+2.5526e-07j, dtype=torch.complex128))
# ('heat', tensor(8.9193e-06, dtype=torch.float64))
# ['Day = ', 145]
# ['Date = ', Timestamp('1950-05-26 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '26']
# ['Day of Year Minus 1', 145]
# (tensor(2.3166e-07+1.6553e-07j, dtype=torch.complex128), tensor(-1.2872e-07+4.2952e-07j, dtype=torch.complex128))
# ('heat', tensor(4.1177e-05, dtype=torch.float64))
# ['Day = ', 146]
# ['Date = ', Timestamp('1950-05-27 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '27']
# ['Day of Year Minus 1', 146]
# (tensor(2.0053e-07+1.0833e-07j, dtype=torch.complex128), tensor(-2.4023e-07+3.6189e-07j, dtype=torch.complex128))
# ('heat', tensor(4.9549e-06, dtype=torch.float64))
# ['Day = ', 147]
# ['Date = ', Timestamp('1950-05-28 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '28']
# ['Day of Year Minus 1', 147]
# (tensor(2.2135e-07+1.5651e-07j, dtype=torch.complex128), tensor(-3.3041e-07+4.0770e-07j, dtype=torch.complex128))
# ('heat', tensor(6.5293e-06, dtype=torch.float64))
# ['Day = ', 148]
# ['Date = ', Timestamp('1950-05-29 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '29']
# ['Day of Year Minus 1', 148]
# (tensor(-6.2927e-08+1.6172e-07j, dtype=torch.complex128), tensor(-2.6495e-07+9.0080e-08j, dtype=torch.complex128))
# ('heat', tensor(1.8653e-05, dtype=torch.float64))
# ['Day = ', 149]
# ['Date = ', Timestamp('1950-05-30 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '30']
# ['Day of Year Minus 1', 149]
# (tensor(-2.0125e-07+4.4359e-07j, dtype=torch.complex128), tensor(-2.2278e-07+2.4696e-07j, dtype=torch.complex128))
# ('heat', tensor(4.3511e-06, dtype=torch.float64))
# ['Day = ', 150]
# ['Date = ', Timestamp('1950-05-31 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '05', '31']
# ['Day of Year Minus 1', 150]
# (tensor(7.7815e-08+4.1973e-07j, dtype=torch.complex128), tensor(-3.9157e-07+2.3442e-07j, dtype=torch.complex128))
# ('heat', tensor(6.7419e-06, dtype=torch.float64))
# ['Day = ', 151]
# ['Date = ', Timestamp('1950-06-01 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '06', '01']
# ['Day of Year Minus 1', 151]
# (tensor(-1.7010e-07+3.8879e-07j, dtype=torch.complex128), tensor(-2.3884e-07+2.5668e-07j, dtype=torch.complex128))
# ('heat', tensor(-6.2470e-06, dtype=torch.float64))
# ['Day = ', 152]
# ['Date = ', Timestamp('1950-06-02 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '06', '02']
# ['Day of Year Minus 1', 152]
# (tensor(-1.6999e-07+6.0309e-07j, dtype=torch.complex128), tensor(-5.3665e-07+4.4794e-07j, dtype=torch.complex128))
# ('heat', tensor(-7.7162e-06, dtype=torch.float64))
# ['Day = ', 153]
# ['Date = ', Timestamp('1950-06-03 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '06', '03']
# ['Day of Year Minus 1', 153]
# (tensor(-8.7021e-08+5.4620e-07j, dtype=torch.complex128), tensor(-2.9636e-07+2.9072e-07j, dtype=torch.complex128))
# ('heat', tensor(1.6298e-05, dtype=torch.float64))
# ['Day = ', 154]
# ['Date = ', Timestamp('1950-06-04 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '06', '04']
# ['Day of Year Minus 1', 154]
# (tensor(-1.7558e-07+5.3017e-07j, dtype=torch.complex128), tensor(-1.7386e-07+3.2786e-07j, dtype=torch.complex128))
# ('heat', tensor(2.0118e-06, dtype=torch.float64))
# ['Day = ', 155]
# ['Date = ', Timestamp('1950-06-05 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '06', '05']
# ['Day of Year Minus 1', 155]
# (tensor(-3.1721e-07+2.8345e-07j, dtype=torch.complex128), tensor(-2.8376e-07+1.7775e-07j, dtype=torch.complex128))
# ('heat', tensor(1.8801e-05, dtype=torch.float64))
# ['Day = ', 156]
# ['Date = ', Timestamp('1950-06-06 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '06', '06']
# ['Day of Year Minus 1', 156]
# (tensor(-3.6081e-07+5.4192e-07j, dtype=torch.complex128), tensor(-9.2755e-08+1.8429e-07j, dtype=torch.complex128))
# ('heat', tensor(1.0758e-05, dtype=torch.float64))
# ['Day = ', 157]
# ['Date = ', Timestamp('1950-06-07 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '06', '07']
# ['Day of Year Minus 1', 157]
# (tensor(-2.3113e-07+5.9188e-07j, dtype=torch.complex128), tensor(-2.2266e-07+1.2849e-07j, dtype=torch.complex128))
# ('heat', tensor(1.2461e-06, dtype=torch.float64))
# ['Day = ', 158]
# ['Date = ', Timestamp('1950-06-08 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '06', '08']
# ['Day of Year Minus 1', 158]
# ...
# ['Calendar for Annual Cycle', '1950', '11', '05']
# ['Day of Year Minus 1', 308]
# (tensor(1.4067e-07+2.5048e-07j, dtype=torch.complex128), tensor(-6.5587e-07-1.6058e-09j, dtype=torch.complex128))
# ('heat', tensor(6.7403e-05, dtype=torch.float64))
# ['Day = ', 309]
# ['Date = ', Timestamp('1950-11-06 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '06']
# ['Day of Year Minus 1', 309]
# (tensor(5.5523e-08+1.6570e-07j, dtype=torch.complex128), tensor(-3.4971e-07-5.1286e-08j, dtype=torch.complex128))
# ('heat', tensor(3.4376e-06, dtype=torch.float64))
# ['Day = ', 310]
# ['Date = ', Timestamp('1950-11-07 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '07']
# ['Day of Year Minus 1', 310]
# (tensor(9.3613e-08+2.2719e-07j, dtype=torch.complex128), tensor(-4.8903e-07+1.2909e-07j, dtype=torch.complex128))
# ('heat', tensor(8.3554e-06, dtype=torch.float64))
# ['Day = ', 311]
# ['Date = ', Timestamp('1950-11-08 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '08']
# ['Day of Year Minus 1', 311]
# (tensor(9.9907e-08+4.6083e-07j, dtype=torch.complex128), tensor(-4.7700e-07-1.8174e-08j, dtype=torch.complex128))
# ('heat', tensor(3.7811e-05, dtype=torch.float64))
# ['Day = ', 312]
# ['Date = ', Timestamp('1950-11-09 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '09']
# ['Day of Year Minus 1', 312]
# (tensor(3.0000e-07+4.6717e-07j, dtype=torch.complex128), tensor(-5.4914e-07+1.8450e-07j, dtype=torch.complex128))
# ('heat', tensor(1.2176e-05, dtype=torch.float64))
# ['Day = ', 313]
# ['Date = ', Timestamp('1950-11-10 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '10']
# ['Day of Year Minus 1', 313]
# (tensor(2.7811e-07+1.2798e-07j, dtype=torch.complex128), tensor(-4.9813e-07+1.0661e-07j, dtype=torch.complex128))
# ('heat', tensor(3.9356e-06, dtype=torch.float64))
# ['Day = ', 314]
# ['Date = ', Timestamp('1950-11-11 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '11']
# ['Day of Year Minus 1', 314]
# (tensor(1.9643e-07+2.9179e-07j, dtype=torch.complex128), tensor(-4.0974e-07-1.5507e-07j, dtype=torch.complex128))
# ('heat', tensor(6.3559e-07, dtype=torch.float64))
# ['Day = ', 315]
# ['Date = ', Timestamp('1950-11-12 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '12']
# ['Day of Year Minus 1', 315]
# (tensor(8.5724e-08+4.5685e-07j, dtype=torch.complex128), tensor(-4.4771e-07+1.6979e-07j, dtype=torch.complex128))
# ('heat', tensor(7.3377e-06, dtype=torch.float64))
# ['Day = ', 316]
# ['Date = ', Timestamp('1950-11-13 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '13']
# ['Day of Year Minus 1', 316]
# (tensor(2.2041e-07+2.2203e-07j, dtype=torch.complex128), tensor(-3.4514e-07+1.7967e-07j, dtype=torch.complex128))
# ('heat', tensor(1.8201e-06, dtype=torch.float64))
# ['Day = ', 317]
# ['Date = ', Timestamp('1950-11-14 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '14']
# ['Day of Year Minus 1', 317]
# (tensor(1.7706e-07+8.5577e-08j, dtype=torch.complex128), tensor(-4.5514e-07+2.5599e-07j, dtype=torch.complex128))
# ('heat', tensor(4.0720e-06, dtype=torch.float64))
# ['Day = ', 318]
# ['Date = ', Timestamp('1950-11-15 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '15']
# ['Day of Year Minus 1', 318]
# (tensor(-8.8794e-08+2.5306e-07j, dtype=torch.complex128), tensor(-3.7744e-07+2.8290e-08j, dtype=torch.complex128))
# ('heat', tensor(4.3189e-05, dtype=torch.float64))
# ['Day = ', 319]
# ['Date = ', Timestamp('1950-11-16 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '16']
# ['Day of Year Minus 1', 319]
# (tensor(-5.6427e-08+4.2615e-07j, dtype=torch.complex128), tensor(-3.5224e-07+3.1958e-07j, dtype=torch.complex128))
# ('heat', tensor(1.2814e-05, dtype=torch.float64))
# ['Day = ', 320]
# ['Date = ', Timestamp('1950-11-17 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '17']
# ['Day of Year Minus 1', 320]
# (tensor(2.4102e-07+3.9710e-07j, dtype=torch.complex128), tensor(-4.1737e-07+2.0740e-07j, dtype=torch.complex128))
# ('heat', tensor(-5.9819e-07, dtype=torch.float64))
# ['Day = ', 321]
# ['Date = ', Timestamp('1950-11-18 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '18']
# ['Day of Year Minus 1', 321]
# (tensor(1.3472e-07+3.9888e-08j, dtype=torch.complex128), tensor(-1.3792e-07+1.0153e-07j, dtype=torch.complex128))
# ('heat', tensor(-1.0871e-06, dtype=torch.float64))
# ['Day = ', 322]
# ['Date = ', Timestamp('1950-11-19 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '19']
# ['Day of Year Minus 1', 322]
# (tensor(-6.7742e-08+3.1866e-07j, dtype=torch.complex128), tensor(-4.2247e-07+1.9316e-07j, dtype=torch.complex128))
# ('heat', tensor(-8.7310e-06, dtype=torch.float64))
# ['Day = ', 323]
# ['Date = ', Timestamp('1950-11-20 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '20']
# ['Day of Year Minus 1', 323]
# (tensor(3.8045e-08+5.2442e-07j, dtype=torch.complex128), tensor(-3.2654e-07+2.0524e-07j, dtype=torch.complex128))
# ('heat', tensor(1.4770e-05, dtype=torch.float64))
# ['Day = ', 324]
# ['Date = ', Timestamp('1950-11-21 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '21']
# ['Day of Year Minus 1', 324]
# (tensor(-9.5436e-09+5.6193e-07j, dtype=torch.complex128), tensor(-1.7607e-07+2.4296e-07j, dtype=torch.complex128))
# ('heat', tensor(1.1429e-05, dtype=torch.float64))
# ['Day = ', 325]
# ['Date = ', Timestamp('1950-11-22 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '22']
# ['Day of Year Minus 1', 325]
# (tensor(-2.0210e-07+5.7564e-07j, dtype=torch.complex128), tensor(-2.1059e-07+1.4900e-07j, dtype=torch.complex128))
# ('heat', tensor(7.1957e-05, dtype=torch.float64))
# ['Day = ', 326]
# ['Date = ', Timestamp('1950-11-23 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '23']
# ['Day of Year Minus 1', 326]
# (tensor(-1.0166e-07+6.7687e-07j, dtype=torch.complex128), tensor(-1.8074e-07+3.0106e-07j, dtype=torch.complex128))
# ('heat', tensor(2.9759e-05, dtype=torch.float64))
# ['Day = ', 327]
# ['Date = ', Timestamp('1950-11-24 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '24']
# ['Day of Year Minus 1', 327]
# (tensor(-1.5487e-07+6.4676e-07j, dtype=torch.complex128), tensor(-3.8603e-07+1.8810e-07j, dtype=torch.complex128))
# ('heat', tensor(4.4577e-05, dtype=torch.float64))
# ['Day = ', 328]
# ['Date = ', Timestamp('1950-11-25 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '25']
# ['Day of Year Minus 1', 328]
# (tensor(-1.1600e-07+5.8444e-07j, dtype=torch.complex128), tensor(-5.7221e-08+2.2690e-07j, dtype=torch.complex128))
# ('heat', tensor(2.5796e-05, dtype=torch.float64))
# ['Day = ', 329]
# ['Date = ', Timestamp('1950-11-26 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '26']
# ['Day of Year Minus 1', 329]
# (tensor(-1.0658e-07+3.5501e-07j, dtype=torch.complex128), tensor(-1.7537e-07+5.7586e-08j, dtype=torch.complex128))
# ('heat', tensor(1.1148e-05, dtype=torch.float64))
# ['Day = ', 330]
# ['Date = ', Timestamp('1950-11-27 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '27']
# ['Day of Year Minus 1', 330]
# (tensor(-3.4466e-07+2.6645e-07j, dtype=torch.complex128), tensor(-1.4114e-07+1.1024e-07j, dtype=torch.complex128))
# ('heat', tensor(-1.7898e-06, dtype=torch.float64))
# ['Day = ', 331]
# ['Date = ', Timestamp('1950-11-28 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '28']
# ['Day of Year Minus 1', 331]
# (tensor(-4.7331e-07+3.8066e-07j, dtype=torch.complex128), tensor(-1.0482e-07+1.5879e-07j, dtype=torch.complex128))
# ('heat', tensor(-8.1447e-06, dtype=torch.float64))
# ['Day = ', 332]
# ['Date = ', Timestamp('1950-11-29 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '29']
# ['Day of Year Minus 1', 332]
# (tensor(-3.2299e-07+3.5825e-07j, dtype=torch.complex128), tensor(-2.2296e-07+1.0392e-07j, dtype=torch.complex128))
# ('heat', tensor(2.0369e-06, dtype=torch.float64))
# ['Day = ', 333]
# ['Date = ', Timestamp('1950-11-30 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '11', '30']
# ['Day of Year Minus 1', 333]
# (tensor(-2.1624e-07+4.0909e-07j, dtype=torch.complex128), tensor(-4.8183e-08+1.4284e-07j, dtype=torch.complex128))
# ('heat', tensor(1.1092e-05, dtype=torch.float64))
# ['Day = ', 334]
# ['Date = ', Timestamp('1950-12-01 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '01']
# ['Day of Year Minus 1', 334]
# (tensor(-3.7799e-07+4.3551e-07j, dtype=torch.complex128), tensor(-1.2664e-07+1.7032e-07j, dtype=torch.complex128))
# ('heat', tensor(-8.6094e-06, dtype=torch.float64))
# ['Day = ', 335]
# ['Date = ', Timestamp('1950-12-02 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '02']
# ['Day of Year Minus 1', 335]
# (tensor(-5.4476e-07+5.5346e-07j, dtype=torch.complex128), tensor(9.5590e-08+5.8983e-08j, dtype=torch.complex128))
# ('heat', tensor(-8.3842e-06, dtype=torch.float64))
# ['Day = ', 336]
# ['Date = ', Timestamp('1950-12-03 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '03']
# ['Day of Year Minus 1', 336]
# (tensor(-3.1529e-07+8.9229e-07j, dtype=torch.complex128), tensor(6.3486e-08+1.5456e-07j, dtype=torch.complex128))
# ('heat', tensor(5.6647e-06, dtype=torch.float64))
# ['Day = ', 337]
# ['Date = ', Timestamp('1950-12-04 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '04']
# ['Day of Year Minus 1', 337]
# (tensor(-7.7682e-08+9.0517e-07j, dtype=torch.complex128), tensor(-2.2578e-07+1.4378e-07j, dtype=torch.complex128))
# ('heat', tensor(-5.3816e-06, dtype=torch.float64))
# ['Day = ', 338]
# ['Date = ', Timestamp('1950-12-05 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '05']
# ['Day of Year Minus 1', 338]
# (tensor(-2.8602e-07+6.3650e-07j, dtype=torch.complex128), tensor(-1.9253e-08+6.8803e-08j, dtype=torch.complex128))
# ('heat', tensor(-5.5232e-06, dtype=torch.float64))
# ['Day = ', 339]
# ['Date = ', Timestamp('1950-12-06 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '06']
# ['Day of Year Minus 1', 339]
# (tensor(-1.0100e-07+6.8009e-07j, dtype=torch.complex128), tensor(-1.2348e-07+8.1817e-08j, dtype=torch.complex128))
# ('heat', tensor(7.1545e-05, dtype=torch.float64))
# ['Day = ', 340]
# ['Date = ', Timestamp('1950-12-07 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '07']
# ['Day of Year Minus 1', 340]
# (tensor(1.7699e-08+6.6185e-07j, dtype=torch.complex128), tensor(-1.3087e-07+1.4213e-07j, dtype=torch.complex128))
# ('heat', tensor(-1.9353e-05, dtype=torch.float64))
# ['Day = ', 341]
# ['Date = ', Timestamp('1950-12-08 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '08']
# ['Day of Year Minus 1', 341]
# (tensor(1.9835e-07+2.6793e-07j, dtype=torch.complex128), tensor(-2.7375e-07+1.2269e-07j, dtype=torch.complex128))
# ('heat', tensor(3.3839e-05, dtype=torch.float64))
# ['Day = ', 342]
# ['Date = ', Timestamp('1950-12-09 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '09']
# ['Day of Year Minus 1', 342]
# (tensor(-5.8176e-08+3.3118e-07j, dtype=torch.complex128), tensor(-1.1729e-07+2.0332e-07j, dtype=torch.complex128))
# ('heat', tensor(4.3898e-05, dtype=torch.float64))
# ['Day = ', 343]
# ['Date = ', Timestamp('1950-12-10 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '10']
# ['Day of Year Minus 1', 343]
# (tensor(-1.7743e-07+5.1931e-07j, dtype=torch.complex128), tensor(-2.6341e-07+3.1651e-07j, dtype=torch.complex128))
# ('heat', tensor(-2.1050e-05, dtype=torch.float64))
# ['Day = ', 344]
# ['Date = ', Timestamp('1950-12-11 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '11']
# ['Day of Year Minus 1', 344]
# (tensor(-7.2647e-08+4.3381e-07j, dtype=torch.complex128), tensor(-1.6197e-07+1.0597e-07j, dtype=torch.complex128))
# ('heat', tensor(1.5911e-05, dtype=torch.float64))
# ['Day = ', 345]
# ['Date = ', Timestamp('1950-12-12 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '12']
# ['Day of Year Minus 1', 345]
# (tensor(8.0112e-08+4.6918e-07j, dtype=torch.complex128), tensor(-1.4382e-07+1.8844e-07j, dtype=torch.complex128))
# ('heat', tensor(7.4125e-06, dtype=torch.float64))
# ['Day = ', 346]
# ['Date = ', Timestamp('1950-12-13 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '13']
# ['Day of Year Minus 1', 346]
# (tensor(-1.8668e-07+3.3947e-07j, dtype=torch.complex128), tensor(-1.7568e-07+1.9245e-08j, dtype=torch.complex128))
# ('heat', tensor(2.8394e-05, dtype=torch.float64))
# ['Day = ', 347]
# ['Date = ', Timestamp('1950-12-14 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '14']
# ['Day of Year Minus 1', 347]
# (tensor(-2.7752e-07+5.6402e-07j, dtype=torch.complex128), tensor(-7.2973e-09+8.4616e-08j, dtype=torch.complex128))
# ('heat', tensor(9.4764e-06, dtype=torch.float64))
# ['Day = ', 348]
# ['Date = ', Timestamp('1950-12-15 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '15']
# ['Day of Year Minus 1', 348]
# (tensor(-2.1711e-07+5.2928e-07j, dtype=torch.complex128), tensor(-1.7502e-07+9.4469e-08j, dtype=torch.complex128))
# ('heat', tensor(1.9955e-05, dtype=torch.float64))
# ['Day = ', 349]
# ['Date = ', Timestamp('1950-12-16 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '16']
# ['Day of Year Minus 1', 349]
# (tensor(-3.2421e-07+4.9810e-07j, dtype=torch.complex128), tensor(-1.1189e-07+2.8135e-07j, dtype=torch.complex128))
# ('heat', tensor(4.1057e-05, dtype=torch.float64))
# ['Day = ', 350]
# ['Date = ', Timestamp('1950-12-17 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '17']
# ['Day of Year Minus 1', 350]
# (tensor(-2.7892e-07+5.4316e-07j, dtype=torch.complex128), tensor(-5.1601e-08+3.0008e-07j, dtype=torch.complex128))
# ('heat', tensor(-8.4239e-06, dtype=torch.float64))
# ['Day = ', 351]
# ['Date = ', Timestamp('1950-12-18 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '18']
# ['Day of Year Minus 1', 351]
# (tensor(-1.0879e-07+8.3134e-07j, dtype=torch.complex128), tensor(-1.0784e-07+3.3028e-07j, dtype=torch.complex128))
# ('heat', tensor(5.8278e-05, dtype=torch.float64))
# ['Day = ', 352]
# ['Date = ', Timestamp('1950-12-19 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '19']
# ['Day of Year Minus 1', 352]
# (tensor(1.0806e-07+6.7553e-07j, dtype=torch.complex128), tensor(8.5221e-09+4.2683e-07j, dtype=torch.complex128))
# ('heat', tensor(5.4857e-05, dtype=torch.float64))
# ['Day = ', 353]
# ['Date = ', Timestamp('1950-12-20 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '20']
# ['Day of Year Minus 1', 353]
# (tensor(-8.3154e-08+4.2316e-07j, dtype=torch.complex128), tensor(2.2098e-08+3.1911e-07j, dtype=torch.complex128))
# ('heat', tensor(2.1306e-05, dtype=torch.float64))
# ['Day = ', 354]
# ['Date = ', Timestamp('1950-12-21 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '21']
# ['Day of Year Minus 1', 354]
# (tensor(-6.1162e-08+4.9925e-07j, dtype=torch.complex128), tensor(-5.2800e-08+3.1918e-07j, dtype=torch.complex128))
# ('heat', tensor(4.6574e-05, dtype=torch.float64))
# ['Day = ', 355]
# ['Date = ', Timestamp('1950-12-22 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '22']
# ['Day of Year Minus 1', 355]
# (tensor(1.2850e-07+4.4049e-07j, dtype=torch.complex128), tensor(-8.6334e-08+3.0952e-07j, dtype=torch.complex128))
# ('heat', tensor(6.0177e-05, dtype=torch.float64))
# ['Day = ', 356]
# ['Date = ', Timestamp('1950-12-23 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '23']
# ['Day of Year Minus 1', 356]
# (tensor(2.3994e-07+6.5751e-07j, dtype=torch.complex128), tensor(-8.6465e-08+1.5006e-07j, dtype=torch.complex128))
# ('heat', tensor(4.8888e-05, dtype=torch.float64))
# ['Day = ', 357]
# ['Date = ', Timestamp('1950-12-24 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '24']
# ['Day of Year Minus 1', 357]
# (tensor(5.3513e-07+4.3533e-07j, dtype=torch.complex128), tensor(-9.8982e-08+3.9981e-07j, dtype=torch.complex128))
# ('heat', tensor(7.3842e-06, dtype=torch.float64))
# ['Day = ', 358]
# ['Date = ', Timestamp('1950-12-25 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '25']
# ['Day of Year Minus 1', 358]
# (tensor(3.8044e-07+4.0384e-07j, dtype=torch.complex128), tensor(-2.6942e-07+2.6167e-07j, dtype=torch.complex128))
# ('heat', tensor(1.4447e-05, dtype=torch.float64))
# ['Day = ', 359]
# ['Date = ', Timestamp('1950-12-26 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '26']
# ['Day of Year Minus 1', 359]
# (tensor(5.8676e-07+3.4932e-07j, dtype=torch.complex128), tensor(-8.9691e-08+3.1416e-07j, dtype=torch.complex128))
# ('heat', tensor(6.2594e-05, dtype=torch.float64))
# ['Day = ', 360]
# ['Date = ', Timestamp('1950-12-27 00:00:00')]
# ['Calendar for Annual Cycle', '1950', '12', '27']
# ['Day of Year Minus 1', 360]

# %%
## Write spectral data for possible restart
##
torch.save(zmn1,datapath+'zmn1.spectral.pt')
torch.save(zmn2,datapath+'zmn2.spectral.pt')
torch.save(dmn1,datapath+'dmn1.spectral.pt')
torch.save(dmn2,datapath+'dmn2.spectral.pt')
torch.save(tmn1,datapath+'tmn1.spectral.pt')
torch.save(tmn2,datapath+'tmn2.spectral.pt')
torch.save(qmn1,datapath+'qmn1.spectral.pt')
torch.save(qmn2,datapath+'qmn2.spectral.pt')
